# %%
import pandas as pd
import numpy as np
tesla=pd.read_csv("TSLA.csv",parse_dates=["Date"])

# %%
tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1    2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2    2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3    2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4    2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...         ...         ...         ...         ...         ...         ...
# 2411 2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412 2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413 2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414 2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415 2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
tesla.plot(x="Date",y=["Open","High","Close","Low"],figsize=(30,10))#,color=("Red","Green","Green","Red"))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
datanot2020 = tesla[tesla['Date'].dt.year != 2020]
data2020 = tesla[tesla['Date'].dt.year == 2020]
data2020.plot(x="Date",y=["Open","High","Close","Low"],figsize=(30,10))#,color=("Red","Green","Green","Red"))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def avtesla(stock_price):
    meanvalue=tesla["Close"].mean()
    if stock_price >=meanvalue:
        return "Above Average"
    else:
        return "Below Average"
plotdata=tesla["Close"].apply(avtesla).value_counts()

# %%
plotdata.plot.pie(autopct='%1.1f%%',legend=True)
# Out:
# <AxesSubplot:ylabel='Close'>

# %%
plotdata.to_frame().plot.bar()
# Out:
# <AxesSubplot:>

# %%
tesla.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object
